# %% [markdown]
# The problem
#
#
# I´m helping a company founded in 2019 that sells pet accesories in Costa Rica. I´m keeping the name confidential, but I have a close relationship with the owners and I wanted to help them to identify the areas where there are more competitors. This data will be compared to their database of costumers in order to identify possible locations to open a store (so far they just do online retail).

# %% [markdown]
# The data:
#
# I´m going to use Foursquare data to pull information on Pet Stores in Costa Rica and make clusters based on the venue latitude and longitude, and the distance between stores
